# %%
from hyperopt import fmin, STATUS_OK, Trials, hp, tpe, rand
import lightgbm
import pandas as pd 
import numpy as np
from pathlib import Path
import os 
import sys 

home_dir = '/Users/Liu'
scripts_dir = os.path.join(home_dir, 'NBA_Pro_Line_Analytics/GBM_model_build')
sys.path.insert(1, scripts_dir)

import model_build_scripts
from model_build_scripts import helpers
from model_build_scripts.NBA_model_build import NBA_Model_Build

# %%
#Defines the model scenario in ./configs/scenarios_config.yml
model_name = "GBM_three_way_outcome_model_build_all_features"

# %%
home_dir = Path(home_dir)
scenario_dir = home_dir / 'NBA_Pro_Line_Analytics' / 'GBM_model_build' / 'scenarios_config.yml'
feature_dir = home_dir / 'NBA_Pro_Line_Analytics' / 'GBM_model_build' / 'features_config.yml'
model_scenario = NBA_Model_Build(model_name, 
                                 feature_yaml = feature_dir, 
                                 scenario_yaml = scenario_dir)
# Out:
# /Users/Liu/NBA_Pro_Line_Analytics/GBM_model_build/model_build_scripts/helpers.py:14: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(stream)

# %%
model_scenario.load_data()

# %%
initial_params = {'objective': 'multiclass',
                  'metric': 'multi_logloss',
                  'num_boost_round': 1000,
                  'early_stopping_rounds': 20,
                  'num_classes': 3,
                  'max_depth': 15,
                  'seed': model_scenario.seed
                 }

# %%
#Runs Recursive Feature Elimination to Remove all features of 0 Importance
post_rfe_model, var_importance  = model_scenario.run_rfe(model_params= initial_params, 
                                                         target = model_scenario.target, X_vars= model_scenario.X_vars)
# Out:
# /Users/Liu/anaconda3/envs/gbmbuild/lib/python3.7/site-packages/lightgbm/engine.py:148: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# /Users/Liu/anaconda3/envs/gbmbuild/lib/python3.7/site-packages/lightgbm/engine.py:153: UserWarning: Found `early_stopping_rounds` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# 288 features below threshold
# The following features will be removed:
# ['Num_Players_3plus_TO_L5G_HT', 'Num_Players_2plus_BL_L7G_RT', 'HT_Win_LG', 'HT_cnt_within_5_L3G', 'Num_Players_1plus_BL_L9G_RT', 'Num_Players_15plus_TOT_L4G_RT', 'Num_Players_25plus_PPG_LG_HT', 'Num_Players_5plus_APG_L3G_RT', 'Num_Players_3plus_ST_L10G_HT', 'Num_Players_5plus_TOT_L6G_RT', 'Num_Players_5plus_TO_L5G_HT', 'Num_Players_5plus_APG_L8G_HT', 'Num_Players_15plus_TOT_L10G_RT', 'Num_Players_3plus_BL_L6G_RT', 'Num_Players_2plus_BL_L8G_HT', 'Num_Players_10plus_APG_L9G_RT', 'Num_Players_10plus_APG_L8G_RT', 'Num_Players_5plus_TO_L7G_RT', 'Num_Players_25plus_PPG_L2G_RT', 'Num_Players_30plus_PPG_L5G_HT', 'Num_Players_15plus_TOT_L8G_RT', 'Num_Players_20plus_PPG_L5G_HT', 'Num_Players_3plus_ST_L3G_RT', 'HT_num_11_plus_pts_wins_L4G', 'Num_Players_15plus_APG_L7G_HT', 'Num_Players_30plus_PPG_L5G_RT', 'Num_Players_3plus_ST_L8G_RT', 'Num_Players_5plus_APG_L6G_RT', 'HT_Num_Wins_L8G', 'RT_cnt_within_5_L8G', 'RT_Num_Losses_L10G', 'Num_Players_15plus_TOT_L9G_HT', 'RT_cnt_wins_6_plus_L2G', 'RT_num_11_plus_pts_loss_L3G', 'Num_Players_30plus_PPG_L10G_RT', 'Num_Players_5plus_TO_L5G_RT', 'Num_Players_2plus_ST_L4G_HT', 'RT_AVG_Loss_PTdiff_L7G', 'Num_Players_15plus_APG_L3G_RT', 'Num_Players_30plus_PPG_L6G_RT', 'Num_Players_10plus_TOT_L8G_HT', 'Num_Players_15plus_APG_L7G_RT', 'RT_Num_Losses_L5G', 'HT_cnt_wins_6_plus_L2G', 'RT_num_11_plus_pts_loss_L8G', 'Num_Players_2plus_ST_L8G_RT', 'HT_Num_Losses_L5G', 'Num_Players_3plus_ST_L6G_RT', 'Num_Players_10plus_APG_L3G_HT', 'RT_cnt_loss_6_plus_L3G', 'HT_AVG_Loss_PTdiff_L10G', 'Num_Players_10plus_APG_L8G_HT', 'Num_Players_3plus_BL_L5G_RT', 'Num_Players_3plus_ST_L10G_RT', 'Num_Players_10plus_TOT_L10G_HT', 'Num_Players_15plus_TOT_L5G_RT', 'Num_Players_15plus_APG_L6G_RT', 'Num_Players_2plus_BL_L6G_HT', 'Num_Players_5plus_TO_LG_HT', 'Num_Players_2plus_ST_L7G_RT', 'Num_Players_10plus_APG_L7G_RT', 'Num_Players_5plus_TO_L3G_RT', 'Num_Players_5plus_TOT_L2G_HT', 'Num_Players_15plus_APG_LG_RT', 'Num_Players_2plus_BL_L4G_HT', 'RT_Win_LG', 'Num_Players_15plus_APG_L10G_HT', 'Num_Players_15plus_APG_L10G_RT', 'HT_cnt_wins_6_plus_L3G', 'Num_Players_25plus_PPG_L8G_HT', 'HT_AVG_Loss_PTdiff_L5G', 'Num_Players_15plus_TOT_L10G_HT', 'Num_Players_1plus_BL_L5G_RT', 'Num_Players_10plus_APG_L9G_HT', 'Num_Players_15plus_TOT_L9G_RT', 'HT_num_11_plus_pts_wins_LG', 'Num_Players_2plus_BL_L3G_RT', 'RT_cnt_within_5_L4G', 'RT_AVG_Win_PTdiff_L4G', 'RT_AVG_Win_PTdiff_L3G', 'Num_Players_30plus_PPG_L7G_RT', 'Num_Players_3plus_BL_L9G_RT', 'Num_Players_3plus_TO_L7G_HT', 'Num_Players_1plus_BL_L3G_HT', 'RT_cnt_loss_6_plus_LG', 'RT_AVG_Win_PTdiff_L8G', 'Num_Players_30plus_PPG_L4G_RT', 'HT_Num_Wins_L10G', 'RT_cnt_wins_6_plus_L3G', 'Num_Players_3plus_BL_LG_HT', 'Num_Players_3plus_ST_L6G_HT', 'Num_Players_3plus_BL_L8G_RT', 'HT_AVG_Loss_PTdiff_LG', 'Num_Players_15plus_APG_L5G_RT', 'Num_Players_10plus_APG_L3G_RT', 'Num_Players_15plus_APG_L6G_HT', 'Num_Players_2plus_ST_L6G_RT', 'Num_Players_30plus_PPG_L9G_HT', 'RT_num_11_plus_pts_loss_LG', 'Num_Players_20plus_PPG_L9G_RT', 'Num_Players_2plus_BL_LG_HT', 'HT_AVG_Loss_PTdiff_L2G', 'Num_Players_15plus_APG_L8G_HT', 'Num_Players_30plus_PPG_L2G_RT', 'Num_Players_10plus_APG_L7G_HT', 'Num_Players_25plus_PPG_LG_RT', 'Num_Players_1plus_BL_L7G_RT', 'Num_Players_15plus_PPG_L4G_HT', 'RT_Num_Wins_L6G', 'Num_Players_2plus_ST_L4G_RT', 'Num_Players_5plus_APG_L6G_HT', 'HT_Num_Wins_L4G', 'Num_Players_20plus_PPG_L3G_HT', 'Num_Players_3plus_BL_L7G_RT', 'Num_Players_30plus_PPG_L8G_RT', 'Num_Players_5plus_TO_L2G_HT', 'Num_Players_25plus_PPG_L10G_RT', 'Num_Players_20plus_PPG_L6G_RT', 'Num_Players_10plus_TOT_L9G_HT', 'HT_Num_Losses_L2G', 'HT_num_11_plus_pts_wins_L2G', 'Num_Players_10plus_APG_L6G_RT', 'RT_AVG_Win_PTdiff_L5G', 'Num_Players_5plus_TO_L4G_RT', 'Num_Players_5plus_TO_L9G_RT', 'Num_Players_3plus_BL_L8G_HT', 'HT_Num_Losses_L10G', 'HT_AVG_Win_PTdiff_L8G', 'Num_Players_2plus_ST_L9G_HT', 'RT_AVG_Loss_PTdiff_L10G', 'HT_Num_Wins_L2G', 'Num_Players_15plus_APG_L2G_RT', 'RT_cnt_wins_6_plus_LG', 'Num_Players_30plus_PPG_L7G_HT', ' ...

# %%
initial_params['bagging_freq'] = 1

# %%
#Runs Hyperparameter tuning (Bayesian Optimization) - current scenario set to complete 200 rounds 
best_params, hyperparam_obj = model_scenario.run_hyperopt(model_scenario.hyperopt_param_space, 
                                                          list(post_rfe_model.booster_.feature_name()), 
                                                          model_params = initial_params, 
                                                          fmin_max_evals = model_scenario.fmin_max_evals)
# Out:
# 100%|██████████| 200/200 [1:04:48<00:00, 19.44s/trial, best loss: -0.42337959448864404]

# %%
#Runs Hyperparameter tuning (Bayesian Optimization) - current scenario set to complete 200 rounds 
best_params
# Out:
# {'colsample_bytree': 0.7956792341863412,
#  'learning_rate': 0.024056645123924907,
#  'min_data_in_leaf': 90.0,
#  'num_leaves': 37.0,
#  'reg_alpha': 0.12682563184942588,
#  'reg_lambda': 0.4946371233393574,
#  'subsample': 0.65}

# %%
best_params['num_leaves'] = int(best_params['num_leaves'])
best_params['min_data_in_leaf'] = int(best_params['min_data_in_leaf'])

# %%
static_params =  {'objective': 'multiclass',
                  'metric': 'multi_logloss',
                  'num_boost_round': 1000,
                  'early_stopping_rounds': 20,
                  'num_classes': 3,
                  'max_depth': 15,
                  'seed': model_scenario.seed
                    }

# %%
final_model = lightgbm.LGBMModel(**best_params, **static_params, importance_type = 'gain')

# %%
eval_set = [(model_scenario.df_tune[list(post_rfe_model.booster_.feature_name())], 
             model_scenario.df_tune[model_scenario.target])]

# %%
final_model.fit(X = model_scenario.df_train[list(post_rfe_model.booster_.feature_name())],
                y = model_scenario.df_train[model_scenario.target],
                eval_set = eval_set,
                verbose = False)
# Out:
# LGBMModel(colsample_bytree=0.7956792341863412, early_stopping_rounds=20,
#           importance_type='gain', learning_rate=0.024056645123924907,
#           max_depth=15, metric='multi_logloss', min_data_in_leaf=90,
#           num_boost_round=1000, num_classes=3, num_leaves=37,
#           objective='multiclass', reg_alpha=0.12682563184942588,
#           reg_lambda=0.4946371233393574, seed=2454371, subsample=0.65,
#           verbose=-1)

# %%
model_predictions = final_model.predict(model_scenario.df_validate[post_rfe_model.booster_.feature_name()])

# %%
y_pred =  [np.argmax(i) for i in model_predictions ]

# %%
d = {
    'TEAM_HT' : model_scenario.df_validate['TEAM_HT'],
    'Final_Score_HT' : model_scenario.df_validate['Final_Score_HT'],
    'TEAM_RT' : model_scenario.df_validate['TEAM_RT'],
    'Final_Score_RT': model_scenario.df_validate['Final_Score_RT'],
    'outcome': model_scenario.df_validate['outcome'],
    'model_prediction_0': model_predictions[:, 0],
    'model_prediction_1': model_predictions[:, 1],
    'model_prediction_2': model_predictions[:, 2],
    'model_prediction': y_pred,
}

# %%
model_prediction_df = pd.DataFrame(data = d)

# %%
(model_prediction_df.outcome == model_prediction_df.model_prediction).value_counts()
# Out:
# False    659
# True     653
# dtype: int64

# %%
model_prediction_65 = model_prediction_df[(model_prediction_df.model_prediction_0 > 0.65) |
                                          (model_prediction_df.model_prediction_1 > 0.65) |
                                          (model_prediction_df.model_prediction_2 > 0.65) ]
model_prediction_60 = model_prediction_df[(model_prediction_df.model_prediction_0 > 0.60) |
                                          (model_prediction_df.model_prediction_1 > 0.60) |
                                          (model_prediction_df.model_prediction_2 > 0.60) ]

# %%
(model_prediction_60.outcome == model_prediction_60.model_prediction).value_counts()
# Out:
# True     152
# False     79
# dtype: int64

# %%
model_prediction_60
# Out:
#             TEAM_HT  Final_Score_HT       TEAM_RT  Final_Score_RT  outcome  \
# 11718       Indiana              94       Houston              98        1
# 11724  Golden State             117       Memphis             101        2
# 11737          Utah             117        Dallas             102        2
# 11739     LA Lakers             114     Minnesota             110        1
# 11743  Golden State             111     Milwaukee             134        0
# ...             ...             ...           ...             ...      ...
# 12840       Toronto             115       Orlando              96        2
# 12844  Golden State             121   LA Clippers             129        0
# 12845       Houston             100          Utah              93        2
# 12849       Toronto             108  Philadelphia              95        2
# 12852       Toronto              89  Philadelphia              94        1
#
#        model_prediction_0  model_prediction_1  model_prediction_2  \
# 11718            0.159817            0.232409            0.607775
# 11724            0.125191            0.159691            0.715118
# 11737            0.168482            0.224843            0.606675
# 11739            0.202192            0.191512            0.606297
# 11743            0.208388            0.188782            0.602829
# ...                   ...                 ...                 ...
# 12840            0.096495            0.189980            0.713525
# 12844            0.137720            0.197303            0.664977
# 12845            0.118844            0.240399            0.640757
# 12849            0.156479            0.235291            0.608230
# 12852            0.141755            0.248833            0.609412
#
#        model_prediction
# 11718                 2
# 11724                 2
# 11737                 2
# 11739                 2
# 11743                 2
# ...                 ...
# 12840                 2
# 12844                 2
# 12845                 2
# 12849                 2
# 12852                 2
#
# [231 rows x 9 columns]

# %%
final_model._Booster.feature_name()
# Out:
# ['Num_Players_1plus_BL_L2G_HT',
#  'RT_cnt_wins_6_plus_L8G',
#  'HT_Num_Wins_L6G',
#  'FT_PCT_L9G_HT',
#  'RT_AVG_PTdiff_L7G',
#  'RT_AVG_Win_PTdiff_L10G',
#  'RT_AVG_Loss_PTdiff_L4G',
#  'Num_Players_5plus_TOT_L3G_RT',
#  'Num_Players_15plus_PPG_L9G_HT',
#  'PPG_AVG_L10G_RT',
#  'FG_PCT_L6G_RT',
#  'Num_Players_20plus_PPG_L10G_RT',
#  'BL_AVG_L8G_HT',
#  'Num_Players_2plus_BL_L3G_HT',
#  'PACE_L7G_HT',
#  '3PT_PCT_LG_RT',
#  'Num_Players_1plus_BL_LG_RT',
#  'POSS_L7G_RT',
#  'Num_Players_15plus_PPG_L3G_HT',
#  'RT_num_11_plus_pts_loss_L6G',
#  'Num_Players_1plus_BL_L5G_HT',
#  '3PT_PCT_L10G_RT',
#  'TOT_AVG_L2G_RT',
#  'APG_AVG_L7G_HT',
#  'PPG_AVG_L9G_HT',
#  'OEFF_LG_RT',
#  'DEFF_LG_RT',
#  'Num_Players_10plus_TOT_LG_RT',
#  'BL_AVG_L6G_RT',
#  'OEFF_L2G_HT',
#  'Num_Players_2plus_ST_L2G_HT',
#  'Num_Players_2plus_ST_L2G_RT',
#  'POSS_L2G_RT',
#  'POSS_L4G_HT',
#  'HT_num_11_plus_pts_wins_L8G',
#  'Num_Players_1plus_TO_L9G_RT',
#  'Num_Players_30plus_PPG_L4G_HT',
#  'Num_Players_15plus_PPG_L5G_HT',
#  'ST_AVG_L5G_RT',
#  'Num_Players_10plus_TOT_L5G_RT',
#  '3PT_PCT_L2G_RT',
#  'APG_AVG_L7G_RT',
#  'DEFF_L10G_HT',
#  'ST_AVG_L8G_HT',
#  'Num_Players_1plus_TO_LG_RT',
#  'RT_Num_Losses_L6G',
#  'Num_Players_15plus_PPG_L7G_HT',
#  'PACE_L5G_HT',
#  'PACE_L10G_RT',
#  'FT_PCT_L7G_HT',
#  'ST_AVG_L6G_HT',
#  'FT_PCT_L6G_HT',
#  '3PT_PCT_LG_HT',
#  'POSS_L3G_HT',
#  'RT_Num_Wins_L7G',
#  'Num_Players_2plus_ST_L3G_HT',
#  'RT_num_11_plus_pts_loss_L5G',
#  'OEFF_L7G_RT',
#  'Num_Players_2plus_ST_L5G_HT',
#  'BL_LG_RT',
#  'HT_AVG_Win_PTdiff_L10G',
#  'PPG_AVG_L10G_HT',
#  '3PT_PCT_L9G_RT',
#  'TOT_LG_RT',
#  'HT_AVG_PTdiff_L5G',
#  'Num_Players_5plus_TOT_L4G_HT',
#  'RT_num_11_plus_pts_wins_L9G',
#  'Num_Players_2plus_BL_L7G_HT',
#  'OEFF_L7G_HT',
#  'FG_PCT_L5G_HT',
#  'PPG_AVG_L4G_HT',
#  'RT_AVG_Win_PTdiff_L9G',
#  'FT_PCT_L4G_HT',
#  'RT_Num_Losses_L3G',
#  'ST_AVG_L10G_HT',
#  'HT_num_11_plus_pts_loss_L5G',
#  'RT_num_11_plus_pts_wins_L8G',
#  'PPG_AVG_L8G_HT',
#  'APG_AVG_L5G_HT',
#  'Num_Players_1plus_ST_L7G_RT',
#  'DEFF_L4G_RT',
#  'ST_AVG_L7G_HT',
#  'TOT_AVG_L9G_HT',
#  'PPG_AVG_L7G_RT',
#  'RT_AVG_Loss_PTdiff_L8G',
#  'Num_Players_15plus_TOT_L2G_RT',
#  'TOT_LG_HT',
#  'BL_AVG_L4G_RT',
#  'HT_AVG_PTdiff_L8G',
#  'DEFF_L6G_RT',
#  'Num_Players_1plus_TO_L5G_RT',
#  'POSS_L5G_HT',
#  'Num_Players_1plus_TO_L6G_HT',
#  'RT_Num_Wins_L5G',
#  'FG_PCT_L10G_RT',
#  'FG_PCT_L10G_HT',
#  'RT_cnt_wins_6_plus_L5G',
#  'OEFF_L4G_HT',
#  'Num_Players_5plus_TO_LG_RT',
#  'DEFF_L7G_RT',
#  'BL_AVG_L7G_HT',
#  'FG_PCT_L9G_RT',
#  'ST_AVG_L3G_RT',
#  'Num_Players_5plus_TOT_L8G_RT',
#  'HT_num_11_plus_pts_wins_L7G',
#  'DEFF_L7G_HT',
#  'Num_Players_10plus_TOT_L7G_HT',
#  'APG_AVG_L4G_HT',
#  'Num_Players_30plus_PPG_LG_RT',
#  'ST_AVG_L4G_HT',
#  'PACE_L2G_RT',
#  'RT_AVG_PTdiff_L4G',
#  'DEFF_L9G_HT',
#  '3PT_PCT_L7G_HT',
#  'Num_Players_10plus_TOT_L3G_HT',
#  'Num_Players_3plus_TO_L7G_RT',
#  'OEFF_L8G_HT',
#  'APG_AVG_L2G_RT',
#  'RT_num_11_plus_pts_wins_L10G',
#  'Num_Players_5plus_APG_L5G_RT',
#  'Num_Players_2plus_BL_L9G_HT',
#  'HT_cnt_wins_6_plus_L9G',
#  'DEFF_L2G_HT',
#  'RT_AVG_Loss_PTdiff_L9G',
#  'OEFF_L10G_HT',
#  'HT_cnt_loss_6_plus_L10G',
#  'Num_Players_15plus_PPG_L10G_HT',
#  'Num_Players_3plus_TO_L10G_RT',
#  'POSS_L8G_HT',
#  'RT_cnt_within_5_L6G',
#  'Num_Players_1plus_BL_L3G_RT',
#  'RT_cnt_loss_6_plus_L8G',
#  'Num_Players_1plus_ST_L5G_RT',
#  'HT_num_11_plus_pts_loss_L8G',
#  'Num_Players_1plus_BL_L8G_RT',
#  'HT_Num_Wins_L7G',
#  'Num_Players_1plus_ST_L10G_HT',
#  'HT_cnt_loss_6_plus_L4G',
#  'HT_num_11_plus_pts_loss_L6G',
#  'RT_AVG_PTdiff_L5G',
#  'Num_Players_25plus_PPG_L9G_RT',
#  'Num_Players_3plus_TO_LG_RT',
#  'Num_Players_5plus_TOT_L3G_HT',
#  'Num_Players_15plus_PPG_L10G_RT',
#  'HT_AVG_Win_PTdiff_L3G',
#  'Num_Players_2plus_ST_L8G_HT',
#  'Num_Players_15plus_PPG_LG_HT',
#  'TOT_AVG_L5G_HT',
#  'ST_AVG_L8G_RT',
#  'HT_AVG_PTdiff_L10G',
#  'FG_PCT_L7G_HT',
#  'ST_AVG_L9G_HT',
#  'HT_Num_Wins_L9G',
#  'FT_PCT_L10G_HT',
#  'RT_AVG_PTdiff_LG',
#  'FG_PCT_LG_RT',
#  'Num_Players_25plus_PPG_L5G_HT',
#  'OEFF_L5G_RT',
#  'Num_Players_1plus_BL_L6G_HT',
#  'Num_Players_10plus_APG_L2G_RT',
#  'Num_Players_2plus_ST_L6G_HT',
#  'TS_PCT_L4G_RT',
#  'ST_LG_HT',
#  'POSS_L5G_RT',
#  'Num_Players_1plus_ST_L9G_RT',
#  'RT_cnt_wins_6_plus_L10G',
#  'TS_PCT_L7G_RT',
#  'Num_Players_1plus_TO_L8G_RT',
#  'Num_Players_1plus_TO_L6G_RT',
#  'Num_Players_15plus_TOT_L4G_HT',
#  'Num_Players_5plus_APG_L2G_HT',
#  'HT_cnt_loss_6_plus_L5G',
#  'TS_PCT_L6G_RT',
#  'PACE_L5G_RT',
#  'HT_AVG_PTdiff_L4G',
#  'Num_Players_3plus_TO_L4G_RT',
#  'RT_num_11_plus_pts_loss_L2G',
#  'Num_Players_15plus_PPG_L5G_RT',
#  'Num_Players_2plus_ST_LG_RT',
#  'HT_cnt_wins_6_plus_L4G',
#  'Num_Players_1plus_ST_L8G_RT',
#  'Num_Players_3plus_TO_LG_HT',
#  'TOT_AVG_L6G_HT',
#  'BL_AVG_L7G_RT',
#  'Num_Players_3plus_BL_L6G_HT',
#  'Num_Players_1plus_TO_L7G_HT',
#  'FT_PCT_L9G_RT',
#  'Num_Players_25plus_PPG_L4G_HT',
#  'FT_PCT_L2G_RT',
#  'Num_Players_3plus_ST_L5G_HT',
#  'Num_Players_1plus_BL_L4G_RT',
#  'PACE_L6G_RT',
#  'POSS_L10G_HT',
#  'TOT_AVG_L3G_HT',
#  'PPG_AVG_L7G_HT',
#  'PPG_AVG_L6G_RT',
#  'Num_Players_3plus_TO_L6G_RT',
#  'ST_AVG_L7G_RT',
#  'PPG_AVG_L4G_RT',
#  'HT_cnt_within_5_L2G',
#  'FT_PCT_L4G_RT',
#  'HT_cnt_loss_6_plus_L8G',
#  'APG_AVG_L8G_RT',
#  'Num_Players_20plus_PPG_L7G_RT',
#  'Num_Players_1plus_ST_L6G_HT',
#  'Num_Players_25plus_PPG_L10G_HT',
#  'Num_Players_20plus_PPG_L8G_HT',
#  'TOT_AVG_L8G_HT',
#  'BL_AVG_L3G_HT',
#  'DEFF_L9G_RT',
#  'Num_Players_30plus_PPG_L3G_RT',
#  'HT_cnt_within_5_L7G',
#  'HT_num_11_plus_pts_wins_L9G',
#  'DEFF_L5G_RT',
#  'Num_Players_15plus_TOT_LG_HT',
#  'Num_Players_15plus_TOT_L2G_HT',
#  'RT_cnt_within_5_L10G',
#  'Num_Players_3plus_BL_L7G_HT',
#  'Num_Players_15plus_PPG_L2G_HT',
#  'PACE_LG_HT',
#  'TS_PCT_L10G_HT',
#  'DEFF_L8G_HT',
#  'Num_Players_5plus_APG_L4G_HT',
#  'BL_AVG_L5G_RT',
#  'TS_PCT_L8G_HT',
#  'FG_PCT_L2G_RT',
#  'OEFF_L3G_HT',
#  'RT_cnt_within_5_L7G',
#  'HT_cnt_loss_6_plus_L3G',
#  'Num_Players_20plus_PPG_L9G_HT',
#  'RT_AVG_PTdiff_L8G',
#  'OEFF_L10G_RT',
#  'RT_AVG_PTdiff_L9G',
#  'Num_Players_1plus_TO_L8G_HT',
#  'POSS_L6G_RT',
#  'Num_Players_1plus_ST_L2G_RT',
#  'ST_AVG_L2G_HT',
#  'PPG_AVG_L3G_RT',
#  '3PT_PCT_L5G_HT',
#  'HT_cnt_within_5_L6G',
#  'Num_Players_3plus_BL_L4G_RT',
#  'Num_Players_20plus_PPG_L5G_RT',
#  'OEFF_LG_HT',
#  'HT_cnt_loss_6_plus_L6G',
#  'TOT_AVG_L8G_RT',
#  'HT_num_11_plus_pts_loss_L4G',
#  'TOT_AVG_L3G_RT',
#  'Num_Players_2plus_BL_L10G_HT',
#  'TS_PCT_L5G_RT',
#  'Num_Players_20plus_PPG_L3G_RT',
#  'PPG_AVG_L5G_RT',
#  'OEFF_L4G_RT',
#  'HT_cnt_loss_6_plus_LG',
#  'PACE_L7G_RT',
#  'RT_num_11_plus_pts_loss_L10G',
#  'BL_AVG_L10G_RT',
#  'TOT_AVG_L7G_HT',
#  'Num_Players_1plus_TO_L3G_HT',
#  'Num_Players_10plus_APG_L2G_HT',
#  'Num_Players_5plus_APG_L9G_RT',
#  'POSS_L8G_RT',
#  'TS_PCT_L9G_HT',
#  'OEFF_L9G_RT',
#  'FT_PCT_L5G_RT',
#  'APG_AVG_L4G_RT',
#  'Num_Players_3plus_ST_L7G_RT',
#  'Num_Players_5plus_APG_LG_RT',
#  'Num_Players_1plus_ST_L3G_HT',
#  'TOT_AVG_L10G_RT',
#  'Num_Players_1plus_TO_L7G_RT',
#  'PPG_LG_RT',
#  'Num_Players_10plus_TOT_L8G_RT',
#  'APG_AVG_L8G_HT',
#  'HT_AVG_PTdiff_L2G',
#  'Num_Players_30plus_PPG_L10G_HT',
#  'FG_PCT_L3G_RT',
#  'BL_AVG_L4G_HT',
#  '3PT_PCT_L5G_RT',
#  'Num_Players_3plus_TO_L9G_RT',
#  'APG_AVG_L9G_HT',
#  'FG_PCT_L6G_HT',
#  'PPG_AVG_L6G_HT',
#  'Num_Players_2plus_BL_L10G_RT',
#  'TS_PCT_L2G_HT',
#  'PPG_AVG_L5G_HT',
#  'Num_Players_1plus_ST_L2G_HT',
#  'HT_num_11_plus_pts_wins_L5G',
#  'Num_Players_15plus_PPG_L4G_RT',
#  'RT_num_11_plus_pts_wins_L4G',
#  'BL_AVG_L10G_HT',
#  'Num_Players_1plus_ST_L9G_HT',
#  '3PT_PCT_L3G_RT',
#  'Num_Players_2plus_ST_L7G_HT',
#  'Num_Players_2plus_BL_L9G_RT',
#  'Num_Players_3plus_TO_L8G_RT',
#  'Num_Players_1plus_ST_L7G_HT',
#  'BL_AVG_L9G_HT',
#  'BL_AVG_L2G_RT',
#  'TS_PCT_L3G_RT',
#  'FT_PCT_L6G_RT',
#  'RT_num_11_plus_pts_wins_L2G',
#  'Num_Players_20plus_PPG_L10G_HT',
#  'TOT_AVG_L5G_RT',
#  'Num_Players_1plus_ST_LG_HT',
#  'Num_Players_1plus_ST_L10G_RT',
#  'PACE_L8G_RT',
#  'PACE_L9G_HT',
#  'Num_Players_5plus_TOT_L8G_HT',
#  'Num_Players_1plus_TO_L5G_HT',
#  'PPG_AVG_L8G_RT',
#  'Num_Players_5plus_TOT_L6G_HT',
#  'RT_cnt_loss_6_plus_L4G',
#  'Num_Players_20plus_PPG_LG_HT',
#  'ST_LG_RT',
#  'Num_Players_20plus_PPG_L4G_RT',
#  'FT_PCT_L8G_HT',
#  'Num_Players_10plus_APG_L4G_HT',
#  'Num_Players_1plus_BL_L8G_HT',
#  'FT_PCT_L2G_HT',
#  'APG_LG_HT',
#  'HT_cnt_wins_6_plus_L6G',
#  'Num_Players_25plus_PPG_L7G_RT',
#  'APG_AVG_L2G_HT',
#  'HT_num_11_plus_pts_wins_L10G',
#  'HT_cnt_within_5_LG',
#  'Num_Players_5plus_APG_L7G_RT',
#  'Num_Players_10plus_TOT_LG_HT',
#  'POSS_L9G_HT',
#  'APG_AVG_L10G_HT',
#  'Num_Players_1plus_BL_L4G_HT',
#  'HT_cnt_within_5_L5G',
#  'Num_Players_15plus_PPG_L8G_RT',
#  'DEFF_L5G_HT',
#  'Num_Players_25plus_PPG_L4G_RT',
#  'Num_Players_5plus_TOT_L7G_RT',
#  'DEFF_L4G_HT',
#  '3PT_PCT_L9G_HT',
#  'POSS_L9G_RT',
#  'POSS_L3G_RT',
#  'Num_Players_25plus_PPG_L8G_RT',
#  'Num_Players_5plus_APG_L5G_HT',
#  'RT_AVG_PTdiff_L2G',
#  'Num_Players_5plus_TOT_L10G_HT',
#  'TOT_AVG_L6G_RT',
#  'RT_cnt_within_5_L2G',
#  'POSS_L4G_RT',
#  'OEFF_L9G_HT',
#  'Num_Players_10plus_TOT_L5G_HT',
#  'TS_PCT_L7G_HT',
#  'Num_Players_1plus_BL_L2G_RT',
#  'RT_cnt_within_5_L9G',
#  'OEFF_L2G_RT',
#  'ST_AVG_L3G_HT',
#  'Num_Players_5plus_TOT_LG_RT',
#  'HT_cnt_wins_6_plus_L7G',
#  'PACE_L4G_HT',
#  'ST_AVG_L5G_HT',
#  'Num_Players_5plus_TOT_L5G_HT',
#  'PACE_L6G_HT',
#  'HT_AVG_PTdiff_L9G',
#  'Num_Players_20plus_PPG_LG_RT',
#  'Num_Players_2plus_BL_LG_RT',
#  'RT_cnt_loss_6_plus_L10G',
#  'APG_AVG_L10G_RT',
#  'ST_AVG_L6G_RT',
#  'BL_AVG_L6G_HT',
#  'Num_Players_10plus_TOT_L4G_HT',
#  'Num_Players_5plus_TOT_L4G_RT',
#  'RT_cnt_wins_6_plus_L9G',
#  'Num_Players_1plus_TO_L10G_RT',
#  'HT_cnt_wins_6_plus_L5G',
#  'APG_AVG_L9G_RT',
#  'PPG_AVG_L3G_HT',
#  'Num_Players_5plus_APG_L10G_RT',
#  'FG_PCT_L3G_HT',
#  'Num_Players_1plus_BL_L10G_HT',
#  'Num_Players_20plus_PPG_L6G_HT',
#  'FG_PCT_L8G_HT',
#  'HT_num_11_plus_pts_loss_L10G',
#  'FG_PCT_L8G_RT',
#  'Num_Players_20plus_PPG_L2G_HT',
#  'Num_Players_10plus_APG_LG_HT',
#  'FG_PCT_L4G_HT',
#  'FT_PCT_LG_RT',
#  'Num_Players_2plus_BL_L8G_RT',
#  'TOT_AVG_L4G_RT',
#  'POSS_L10G_RT',
#  'PACE_L9G_RT',
#  'Num_Players_1plus_ST_L8G_HT',
#  'Num_Players_1plus_ST_L6G_RT',
#  'Num_Players_2plus_BL_L5G_HT',
#  'OEFF_L6G_HT',
#  'PACE_L4G_RT',
#  'BL_LG_HT',
#  'TS_PCT_L5G_HT',
#  'HT_AVG_PTdiff_L3G',
#  'Num_Players_10plus_APG_L4G_RT',
#  'APG_AVG_L6G_HT',
#  'HT_AVG_Loss_PTdiff_L9G',
#  'Num_Players_1plus_TO_L4G_RT',
#  'BL_AVG_L5G_HT',
#  'PPG_AVG_L9G_RT',
#  'PACE_L8G_HT',
#  '3PT_PCT_L8G_HT',
#  'Num_Players_10plus_TOT_L4G_RT',
#  'Num_Players_1plus_ST_L3G_RT',
#  'Num_Players_3plus_TO_L3G_HT',
#  '3PT_PCT_L10G_HT',
#  'PPG_AVG_L2G_HT',
#  'POSS_L2G_HT',
#  '3PT_PCT_L6G_RT',
#  'TOT_AVG_L10G_HT',
#  'POSS_L7G_HT',
#  '3PT_PCT_L4G_HT',
#  'Num_Players_15plus_PPG_L8G_HT',
#  'DEFF_L3G_RT',
#  'Num_Players_1plus_BL_LG_HT',
#  'Num_Players_1plus_ST_L4G_RT',
#  'FT_PCT_L3G_RT',
#  'Num_Players_15plus_PPG_L7G_RT',
#  'POSS_L6G_HT',
#  'Num_Players_5plus_APG_L3G_HT',
#  'Num_Players_1plus_TO_L9G_HT',
#  'PACE_L3G_HT',
#  'Num_Players_3plus_TO_L2G_HT',
#  'DEFF_L10G_RT',
#  'Num_Players_20plus_PPG_L7G_HT',
#  'Num_Players_1plus_BL_L7G_HT',
#  'FT_PCT_L10G_RT',
#  'TS_PCT_L9G_RT',
#  'Num_Players_5plus_TOT_L10G_RT',
#  '3PT_PCT_L3G_HT',
#  'Num_Players_2plus_ST_LG_HT',
#  'Num_Players_25plus_PPG_L5G_RT',
#  'HT_AVG_PTdiff_L6G',
#  'BL_AVG_L8G_RT',
#  'TS_PCT_L3G_HT',
#  'RT_AVG_PTdiff_L6G',
#  'POSS_LG_RT',
#  'HT_num_11_plus_pts_wins_L6G',
#  'TS_PCT_LG_RT',
#  'PPG_LG_HT',
#  'DEFF_L8G_RT',
#  'PACE_L2G_HT',
#  'Num_Players_5plus_APG_L8G_RT',
#  'Num_Players_1plus_ST_L4G_HT',
#  'OEFF_L8G_RT',
#  'BL_AVG_L9G_RT',
#  'Num_Players_1plus_ST_L5G_HT',
#  'Num_Players_15plus_PPG_LG_RT',
#  'DEFF_LG_HT',
#  'RT_AVG_PTdiff_L3G',
#  'Num_Players_5plus_APG_L10G_HT',
#  'Num_Players_5plus_APG_LG_HT',
#  'OEFF_L5G_HT',
#  'FT_PCT_L7G_RT',
#  'HT_cnt_wins_6_plus_L8G',
#  'Num_Players_20plus_PPG_L2G_RT',
#  'Num_Players_3plus_ST_L7G_HT',
#  'Num_Players_2plus_ST_L3G_RT',
#  'Num_Players_3plus_TO_L3G_RT',
#  'Num_Players_1plus_BL_L10G_RT',
#  'Num_Players_1plus_TO_L10G_HT',
#  'RT_num_11_plus_pts_wins_L3G',
#  'FG_PCT_L9G_HT',
#  'FG_PCT_L4G_RT',
#  'Num_Players_3plus_ST_LG_HT',
#  'RT_cnt_wins_6_plus_L7G',
#  'TS_PCT_L10G_RT',
#  '3PT_PCT_L7G_RT',
#  'FT_PCT_LG_HT',
#  'Num_Players_30plus_PPG_L2G_HT',
#  'Num_Players_20plus_PPG_L8G_RT',
#  '3PT_PCT_L2G_HT',
#  'RT_cnt_within_5_L5G',
#  'FG_PCT_L7G_RT',
#  'Num_Players_5plus_TOT_L5G_RT',
#  'Num_Players_20plus_PPG_L4G_HT',
#  'Num_Players_15plus_PPG_L6G_RT',
#  'DEFF_L6G_HT',
#  'Num_Players_5plus_APG_L9G_HT',
#  'BL_AVG_L3G_RT',
#  'TOT_AVG_L7G_RT',
#  'Num_Players_10plus_APG_L5G_RT',
#  '3PT_PCT_L6G_HT',
#  'HT_num_11_plus_pts_wins_L3G',
#  'Num_Players_1plus_TO_L3G_RT',
#  'HT_AVG_PTdiff_L7G',
#  'Num_Players_15plus_PPG_L2G_RT',
#  'TS_PCT_LG_HT',
#  'APG_LG_RT',
#  'Num_Players_5plus_APG_L2G_RT',
#  'ST_AVG_L4G_RT',
#  'ST_AVG_L10G_RT',
#  'PPG_AVG_L2G_RT',
#  'FG_PCT_L5G_RT',
#  'POSS_LG_HT',
#  'Num_Players_15plus_PPG_L9G_RT',
#  'ST_AVG_L9G_RT',
#  'Num_Players_1plus_TO_LG_HT',
#  'HT_cnt_within_5_L9G',
#  'RT_cnt_loss_6_plus_L2G',
#  'DEFF_L2G_RT',
#  'RT_num_11_plus_pts_loss_L4G',
#  'HT_cnt_wins_6_plus_L10G',
#  'OEFF_L6G_RT',
#  'RT_cnt_loss_6_plus_L7G',
#  'PACE_L3G_RT',
#  'PACE_LG_RT',
#  'FT_PCT_L3G_HT',
#  'Num_Players_5plus_TOT_LG_HT',
#  'Num_Players_5plus_TOT_L9G_RT',
#  'Num_Players_10plus_TOT_L7G_RT',
#  'HT_cnt_within_5_L8G',
#  'HT_cnt_loss_6_plus_L7G',
#  'RT_cnt_loss_6_plus_L5G',
#  'Num_Players_10plus_TOT_L10G_RT',
#  'RT_num_11_plus_pts_loss_L9G',
#  'Num_Players_3plus_TO_L10G_HT',
#  'Num_Players_1plus_BL_L6G_RT',
#  'TOT_AVG_L9G_RT',
#  'ST_AVG_L2G_RT',
#  'APG_AVG_L5G_RT',
#  'TOT_AVG_L4G_HT',
#  'BL_AVG_L2G_HT',
#  'TS_PCT_L2G_RT',
#  'Num_Players_1plus_TO_L2G_HT',
#  'TS_PCT_L4G_HT',
#  'TOT_AVG_L2G_HT',
#  'FT_PCT_L8G_RT',
#  'FG_PCT_LG_HT',
#  'RT_AVG_PTdiff_L10G',
#  'Num_Players_5plus_TOT_L7G_HT',
#  'RT_cnt_loss_6_plus_L9G',
#  '3PT_PCT_L8G_RT',
#  'FT_PCT_L5G_HT',
#  'FG_PCT_L2G_HT',
#  'HT_cnt_within_5_L4G',
#  'Num_Players_15plus_PPG_L3G_RT',
#  'OEFF_L3G_RT',
#  'PACE_L10G_HT',
#  'Num_Players_1plus_TO_L2G_RT',
#  'HT_num_11_plus_pts_loss_L9G',
#  'DEFF_L3G_HT',
#  'TS_PCT_L6G_HT',
#  'Num_Players_3plus_TO_L2G_RT',
#  'TS_PCT_L8G_RT',
#  'Num_Players_5plus_TOT_L9G_HT',
#  'HT_AVG_PTdiff_LG',
#  '3PT_PCT_L4G_RT',
#  'APG_AVG_L6G_RT',
#  'RT_num_11_plus_pts_loss_L7G']
