# %%
from hyperopt import fmin, STATUS_OK, Trials, hp, tpe, rand
import lightgbm
import pandas as pd 
import numpy as np
from pathlib import Path
import os 
import sys 

home_dir = '/Users/Liu'
scripts_dir = os.path.join(home_dir, 'NBA_Pro_Line_Analytics/GBM_model_build')
sys.path.insert(1, scripts_dir)

import model_build_scripts
from model_build_scripts import helpers
from model_build_scripts.NBA_model_build import NBA_Model_Build

# %%
#Defines the model scenario in ./configs/scenarios_config.yml
model_name = "GBM_tot_score_prediction_model_build_all_features"

# %%
home_dir = Path(home_dir)
scenario_dir = home_dir / 'NBA_Pro_Line_Analytics' / 'GBM_model_build' / 'scenarios_config.yml'
feature_dir = home_dir / 'NBA_Pro_Line_Analytics' / 'GBM_model_build' / 'features_config.yml'
model_scenario = NBA_Model_Build(model_name, 
                                 feature_yaml = feature_dir, 
                                 scenario_yaml = scenario_dir)
# Out:
# /Users/Liu/NBA_Pro_Line_Analytics/GBM_model_build/model_build_scripts/helpers.py:14: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   config = yaml.load(stream)

# %%
model_scenario.load_data()

# %%
initial_params = {'objective': 'regression',
                  'num_boost_round': 1000,
                  'early_stopping_rounds': 20,
                  'max_depth': 15,
                  'seed': model_scenario.seed,
                  'bagging_freq': 1
                 }

# %%
#Runs Recursive Feature Elimination to Remove all features of 0 Importance
post_rfe_model, var_importance  = model_scenario.run_rfe(model_params = initial_params, 
                                                         target = model_scenario.target, 
                                                         X_vars= model_scenario.X_vars,
                                                         model_type = 'regressor')
# Out:
# 524 features below threshold
# The following features will be removed:
# ['HT_Num_Wins_L4G', 'Num_Players_1plus_ST_L7G_RT', 'HT_AVG_Win_PTdiff_L10G', 'Num_Players_1plus_BL_L6G_RT', 'RT_cnt_within_5_L10G', 'Num_Players_3plus_ST_L2G_HT', 'Num_Players_3plus_ST_L10G_RT', 'Num_Players_1plus_ST_L10G_RT', 'Num_Players_3plus_ST_L3G_HT', 'HT_cnt_loss_6_plus_L5G', 'HT_num_11_plus_pts_wins_L4G', 'RT_cnt_loss_6_plus_L6G', 'Num_Players_1plus_BL_L2G_RT', 'Num_Players_15plus_TOT_L4G_HT', 'PPG_AVG_L6G_RT', 'Num_Players_3plus_TO_L5G_RT', 'Num_Players_5plus_TO_L6G_RT', 'HT_Num_Losses_L8G', 'BL_LG_RT', 'Num_Players_1plus_TO_L4G_HT', 'Num_Players_2plus_BL_L2G_RT', 'RT_num_11_plus_pts_loss_L9G', 'HT_AVG_PTdiff_L5G', 'Num_Players_3plus_ST_L6G_HT', 'Num_Players_25plus_PPG_L3G_RT', 'TS_PCT_L2G_RT', 'Num_Players_5plus_TO_L9G_RT', 'Num_Players_15plus_APG_LG_HT', 'HT_cnt_loss_6_plus_L7G', 'Num_Players_3plus_BL_L10G_HT', 'APG_AVG_L3G_HT', 'HT_Num_Wins_L8G', 'Num_Players_10plus_APG_L8G_HT', 'BL_AVG_L3G_HT', 'HT_AVG_Win_PTdiff_L2G', 'HT_num_11_plus_pts_wins_L2G', 'Num_Players_2plus_BL_L3G_RT', 'Num_Players_3plus_BL_L4G_RT', 'RT_Num_Losses_L2G', 'RT_num_11_plus_pts_wins_L4G', 'Num_Players_15plus_PPG_L5G_RT', 'RT_num_11_plus_pts_wins_L2G', 'Num_Players_1plus_TO_L4G_RT', 'Num_Players_5plus_APG_L3G_HT', 'HT_AVG_PTdiff_L8G', 'Num_Players_3plus_ST_L4G_RT', 'RT_cnt_loss_6_plus_L2G', 'Num_Players_2plus_ST_L2G_HT', 'Num_Players_15plus_PPG_L9G_RT', 'Num_Players_10plus_APG_L10G_HT', 'Num_Players_3plus_ST_LG_HT', 'HT_cnt_wins_6_plus_L5G', 'RT_Num_Losses_L9G', 'Num_Players_3plus_BL_L6G_RT', 'RT_cnt_within_5_L9G', 'Num_Players_3plus_ST_L5G_HT', 'Num_Players_5plus_APG_L5G_RT', 'Num_Players_25plus_PPG_L5G_RT', 'HT_num_11_plus_pts_wins_L3G', 'Num_Players_10plus_TOT_L8G_HT', 'Num_Players_10plus_APG_L6G_RT', 'HT_cnt_loss_6_plus_L8G', 'HT_cnt_within_5_L3G', 'RT_num_11_plus_pts_wins_L9G', 'FG_PCT_L9G_HT', 'Num_Players_2plus_ST_L10G_HT', 'Num_Players_10plus_TOT_L4G_RT', 'Num_Players_20plus_PPG_L8G_HT', 'HT_Loss_LG', 'Num_Players_15plus_PPG_L6G_HT', 'Num_Players_30plus_PPG_L4G_RT', 'RT_cnt_wins_6_plus_L9G', 'Num_Players_15plus_APG_L10G_HT', 'Num_Players_3plus_TO_L9G_HT', 'Num_Players_3plus_ST_L8G_HT', 'Num_Players_3plus_ST_L9G_RT', 'Num_Players_30plus_PPG_L9G_RT', 'Num_Players_3plus_TO_L5G_HT', 'Num_Players_15plus_TOT_L7G_RT', 'Num_Players_1plus_ST_L9G_RT', 'BL_LG_HT', 'RT_cnt_within_5_L3G', 'Num_Players_15plus_APG_L5G_RT', 'Num_Players_1plus_TO_L6G_HT', 'Num_Players_3plus_TO_L7G_HT', 'Num_Players_15plus_APG_L2G_HT', 'Num_Players_2plus_ST_L7G_RT', 'ST_AVG_L4G_HT', 'Num_Players_2plus_ST_LG_RT', 'HT_cnt_loss_6_plus_L3G', 'Num_Players_15plus_TOT_LG_RT', 'HT_AVG_Win_PTdiff_L3G', 'RT_num_11_plus_pts_loss_L2G', 'HT_cnt_loss_6_plus_L9G', 'BL_AVG_L8G_HT', 'Num_Players_30plus_PPG_L2G_RT', 'RT_cnt_within_5_L4G', 'Num_Players_15plus_TOT_L7G_HT', 'PPG_AVG_L5G_HT', 'Num_Players_1plus_ST_L2G_HT', 'Num_Players_10plus_APG_L10G_RT', 'Num_Players_5plus_TOT_L5G_RT', 'Num_Players_2plus_BL_L5G_RT', 'Num_Players_10plus_TOT_L5G_HT', 'Num_Players_3plus_BL_L2G_RT', 'Num_Players_30plus_PPG_L7G_HT', 'Num_Players_10plus_APG_L6G_HT', 'HT_AVG_PTdiff_L6G', 'HT_num_11_plus_pts_wins_L6G', 'HT_cnt_loss_6_plus_L2G', 'Num_Players_1plus_ST_L8G_HT', 'HT_cnt_within_5_L10G', 'Num_Players_1plus_ST_L6G_HT', 'Num_Players_15plus_PPG_L9G_HT', 'RT_num_11_plus_pts_wins_L8G', 'RT_cnt_loss_6_plus_L5G', 'Num_Players_2plus_BL_L6G_RT', 'Num_Players_10plus_TOT_L7G_RT', 'Num_Players_25plus_PPG_L5G_HT', 'Num_Players_15plus_PPG_L3G_HT', 'Num_Players_2plus_ST_L6G_HT', 'Num_Players_15plus_PPG_L7G_RT', 'RT_num_11_plus_pts_wins_L10G', 'Num_Players_3plus_BL_L3G_RT', 'HT_num_11_plus_pts_loss_L2G', 'Num_Players_15plus_PPG_L8G_RT', 'Num_Players_15plus_PPG_L8G_HT', 'Num_Players_30plus_PPG_L6G_HT', 'HT_cnt_loss_6_plus_LG', 'Num_Players_15plus_TOT_L3G_RT', 'Num_Players_5plus_APG_L8G_HT', 'Num_Players_3plus_TO_L2G_RT', 'PPG_AVG_L9G_HT', 'ST_AVG_L9G_HT', 'Num_Players_20plus_PPG_L7G_HT', 'FG_PCT_L9G_RT', 'RT_num_11_plus_pts_loss_L7G', 'Num_Players_15plus_TOT_L10G_HT', 'HT_cnt_within_5_L4G', 'RT_Num_Losses_L4G', 'Num_Pl ...

# %%
initial_params['bagging_freq'] = 1

# %%
#Runs Hyperparameter tuning (Bayesian Optimization) - current scenario set to complete 200 rounds 
best_params, hyperparam_obj = model_scenario.run_hyperopt(model_scenario.hyperopt_param_space, 
                                                          model_scenario.X_vars, 
                                                          model_params = initial_params, 
                                                          fmin_max_evals = model_scenario.fmin_max_evals,
                                                          model_type = 'regressor')
# Out:
# 100%|██████████| 200/200 [45:55<00:00, 13.78s/trial, best loss: -0.0]

# %%
#Runs Hyperparameter tuning (Bayesian Optimization) - current scenario set to complete 200 rounds 
best_params
# Out:
# {'colsample_bytree': 0.6489325172213725,
#  'learning_rate': 0.03265285941393413,
#  'min_data_in_leaf': 100.0,
#  'num_leaves': 49.0,
#  'reg_alpha': 0.17948888280944775,
#  'reg_lambda': 0.11267775892310361,
#  'subsample': 0.9}

# %%
best_params['num_leaves'] = int(best_params['num_leaves'])
best_params['min_data_in_leaf'] = int(best_params['min_data_in_leaf'])

# %%
static_params =  {'objective': 'regression',
                  'num_boost_round': 1000,
                  'early_stopping_rounds': 25,
                  'max_depth': 15,
                  'seed': model_scenario.seed,
                  'bagging_freq': 1
                 }

# %%
final_model = lightgbm.LGBMRegressor(**best_params, **static_params, importance_type = 'gain')

# %%
eval_set = [(model_scenario.df_tune[list(post_rfe_model.booster_.feature_name())], 
             model_scenario.df_tune[model_scenario.target])]

# %%
final_model.fit(X = model_scenario.df_train[list(post_rfe_model.booster_.feature_name())],
                y = model_scenario.df_train[model_scenario.target],
                eval_set = eval_set,
                verbose = False)
# Out:
# LGBMRegressor(bagging_freq=1, colsample_bytree=0.6489325172213725,
#               early_stopping_rounds=25, importance_type='gain',
#               learning_rate=0.03265285941393413, max_depth=15,
#               min_data_in_leaf=100, num_boost_round=1000, num_leaves=49,
#               objective='regression', reg_alpha=0.17948888280944775,
#               reg_lambda=0.11267775892310361, seed=2454371, subsample=0.9)

# %%
model_predictions = final_model.predict(model_scenario.df_validate[post_rfe_model.booster_.feature_name()])

# %%
d = {
    'TEAM_HT' : model_scenario.df_validate['TEAM_HT'],
    'Final_Score_HT' : model_scenario.df_validate['Final_Score_HT'],
    'TEAM_RT' : model_scenario.df_validate['TEAM_RT'],
    'Final_Score_RT': model_scenario.df_validate['Final_Score_RT'],
    'tot_score': model_scenario.df_validate[model_scenario.target],
    'outcome': model_scenario.df_validate['cover_over_line'],
    'ht_closing_spread': model_scenario.df_validate['CLOSING TOTAL_HT'],
    'model_prediction': model_predictions
}

# %%
model_prediction_df = pd.DataFrame(data = d)

# %%
model_prediction_df
# Out:
#             TEAM_HT  Final_Score_HT        TEAM_RT  Final_Score_RT  tot_score  \
# 11578        Boston             105   Philadelphia              87        192
# 11579  Golden State             108  Oklahoma City             100        208
# 11580     Charlotte             112      Milwaukee             113        225
# 11581       Detroit             103       Brooklyn             100        203
# 11582       Indiana             111        Memphis              83        194
# ...             ...             ...            ...             ...        ...
# 12885       Toronto             104   Golden State             109        213
# 12886  Golden State             109        Toronto             123        232
# 12887  Golden State              92        Toronto             105        197
# 12888       Toronto             105   Golden State             106        211
# 12889  Golden State             110        Toronto             114        224
#
#        outcome  ht_closing_spread  model_prediction
# 11578        0              211.5        209.441138
# 11579        0              220.5        218.372911
# 11580        1              222.0        218.641438
# 11581        0              213.0        209.945426
# 11582        0              204.5        205.518854
# ...        ...                ...               ...
# 12885        0              213.5        217.684567
# 12886        1              209.5        214.021250
# 12887        0              215.0        218.847866
# 12888        0              217.0        219.812401
# 12889        1              211.5        212.884602
#
# [1312 rows x 8 columns]

# %%
def map_model_prediction(df): 
    if df['model_prediction'] > df['ht_closing_spread']:
        return 1 
    else:
        return 0

# %%
model_prediction_df['prediction_over'] = model_prediction_df.apply(map_model_prediction, axis = 1)

# %%
model_prediction_df
# Out:
#             TEAM_HT  Final_Score_HT        TEAM_RT  Final_Score_RT  tot_score  \
# 11578        Boston             105   Philadelphia              87        192
# 11579  Golden State             108  Oklahoma City             100        208
# 11580     Charlotte             112      Milwaukee             113        225
# 11581       Detroit             103       Brooklyn             100        203
# 11582       Indiana             111        Memphis              83        194
# ...             ...             ...            ...             ...        ...
# 12885       Toronto             104   Golden State             109        213
# 12886  Golden State             109        Toronto             123        232
# 12887  Golden State              92        Toronto             105        197
# 12888       Toronto             105   Golden State             106        211
# 12889  Golden State             110        Toronto             114        224
#
#        outcome  ht_closing_spread  model_prediction  prediction_over
# 11578        0              211.5        209.441138                0
# 11579        0              220.5        218.372911                0
# 11580        1              222.0        218.641438                0
# 11581        0              213.0        209.945426                0
# 11582        0              204.5        205.518854                1
# ...        ...                ...               ...              ...
# 12885        0              213.5        217.684567                1
# 12886        1              209.5        214.021250                1
# 12887        0              215.0        218.847866                1
# 12888        0              217.0        219.812401                1
# 12889        1              211.5        212.884602                1
#
# [1312 rows x 9 columns]

# %%
model_prediction_df['abs_diff']  = abs(model_prediction_df['model_prediction'] - model_prediction_df['ht_closing_spread'])

# %%
model_prediction_df[model_prediction_df.abs_diff > 10]
# Out:
#              TEAM_HT  Final_Score_HT        TEAM_RT  Final_Score_RT  \
# 11586        Houston             112    New Orleans             131
# 11599    New Orleans             149     Sacramento             129
# 11612      LA Lakers             115        Houston             124
# 11613      Cleveland             111        Atlanta             133
# 11615         Denver             100   Golden State              98
# 11627    New Orleans             116    LA Clippers             109
# 11629        Atlanta             111         Dallas             104
# 11637        Phoenix             113      LA Lakers             131
# 11639   Golden State             144     Washington             122
# 11643      LA Lakers             121         Denver             114
# 11648      Minnesota              95      Milwaukee             125
# 11650     Sacramento             116     Washington             112
# 11659    San Antonio             110      LA Lakers             106
# 11670      Minnesota             124      LA Lakers             120
# 11685   Golden State             131    New Orleans             121
# 11701   Golden State             116      Minnesota              99
# 11709       Portland             110      LA Lakers             114
# 11710      Milwaukee             144     Sacramento             109
# 11721  Oklahoma City             122    New Orleans             116
# 11739      LA Lakers             114      Minnesota             110
# 11743   Golden State             111      Milwaukee             134
# 11760     Sacramento              86      LA Lakers             101
# 11766      LA Lakers             107        Atlanta             106
# 11889    New Orleans             125     Washington             104
# 11954      Milwaukee              95   Golden State             105
# 12029        Atlanta             118     Washington             110
# 12069     Sacramento             122    New Orleans             117
# 12088    LA Clippers             127     Sacramento             118
# 12227    LA Clippers             117    New Orleans             121
# 12240   Golden State             147    New Orleans             140
# 12253    LA Clippers              94   Golden State             112
# 12339     Sacramento             135        Atlanta             113
# 12345   Golden State             104   Philadelphia             113
# 12425        Atlanta             117      LA Lakers             113
# 12443    New Orleans             131  Oklahoma City             122
# 12448   Golden State             125     Sacramento             123
# 12467  Oklahoma City             116     Sacramento             119
# 12482      Minnesota             112     Sacramento             105
# 12483    New Orleans             110   Philadelphia             111
# 12487         Denver             121  Oklahoma City             112
# 12491       Brooklyn             116     Washington             125
# 12498      LA Lakers             125    New Orleans             119
# 12504  Oklahoma City             104   Philadelphia             108
# 12509        Phoenix             116    New Orleans             130
# 12510     Sacramento             109    LA Clippers             116
# 12511      LA Lakers             120      Milwaukee             131
# 12515   Philadelphia             117   Golden State             120
# 12518         Denver             112    New Orleans             120
# 12527     Washington             135      Minnesota             121
# 12540      Minnesota             131  Oklahoma City             120
# 12564        Atlanta             112       Brooklyn             114
# 12565      Minnesota             135     Washington             130
# 12579     Washington             121     Sacramento             115
# 12690    New Orleans             120        Atlanta             130
# 12745        Atlanta             130   Philadelphia             122
#
#        tot_score  outcome  ht_closing_spread  model_prediction  \
# 11586        243        1              233.0        221.910278
# 11599        278        1              232.5        220.810240
# 11612        239        1              237.5        220.330425
# 11613        244        1              232.5        221.081314
# 11615        198        0              230.5        218.942088
# 11627        225        0              237.5        222.365427
# 11629        215        0              236.0        223.043984
# 11637        244        1              238.5        222.551176
# 11639        266        1              236.0        222.711037
# 11643        235        1              234.5        221.182247
# 11648        220        0              233.5        222.037997
# 11650        228        0              236.5        222.787633
# 11659        216        0              232.5        222.387490
# 11670        244        1              239.0        223.348833
# 11685        252        1              241.0        225.727121
# 11701        215        0              243.5        227.805874
# 11709        224        0              236.0        224.651590
# 11710        253        1              234.5        224.306154
# 11721        238        1              235.5        224.794751
# 11739        224        0              239.0        226.443057
# 11743        245        1              242.5        229.833310
# 11760        187        0              237.0        226.883242
# 11766        213        0              237.0        226.758230
# 11889        229        0              241.0        228.386492
# 11954        200        0              242.0        231.424872
# 12029        228        0              237.5        226.751641
# 12069        239        1              238.0        226.358740
# 12088        245        1              238.5        226.564691
# 12227        238        0              240.5        228.280746
# 12240        287        1              243.0        225.759241
# 12253        206        0              242.0        228.865803
# 12339        248        1              236.5        225.722248
# 12345        217        0              240.5        228.492974
# 12425        230        0              239.5        227.213422
# 12443        253        1              238.5        227.546832
# 12448        248        1              239.0        226.854081
# 12467        235        0              240.0        227.881745
# 12482        217        0              236.5        225.610534
# 12483        221        0              240.0        228.544116
# 12487        233        0              238.5        228.045054
# 12491        241        1              238.0        226.195833
# 12498        244        1              239.5        226.926882
# 12504        212        0              239.5        228.180960
# 12509        246        1              239.0        227.260511
# 12510        225        0              239.5        229.199993
# 12511        251        1              239.5        229.005483
# 12515        237        0              238.5        227.967614
# 12518        232        0              238.0        227.129427
# 12527        256        1              241.5        225.412763
# 12540        251        1              236.5        225.811886
# 12564        226        0              238.0        226.170322
# 12565        265        1              242.5        230.186226
# 12579        236        0              239.0        225.204224
# 12690        250        1              242.5        228.011815
# 12745        252        1              240.0        226.335340
#
#        prediction_over   abs_diff
# 11586                0  11.089722
# 11599                0  11.689760
# 11612                0  17.169575
# 11613                0  11.418686
# 11615                0  11.557912
# 11627                0  15.134573
# 11629                0  12.956016
# 11637                0  15.948824
# 11639                0  13.288963
# 11643                0  13.317753
# 11648                0  11.462003
# 11650                0  13.712367
# 11659                0  10.112510
# 11670                0  15.651167
# 11685                0  15.272879
# 11701                0  15.694126
# 11709                0  11.348410
# 11710                0  10.193846
# 11721                0  10.705249
# 11739                0  12.556943
# 11743                0  12.666690
# 11760                0  10.116758
# 11766                0  10.241770
# 11889                0  12.613508
# 11954                0  10.575128
# 12029                0  10.748359
# 12069                0  11.641260
# 12088                0  11.935309
# 12227                0  12.219254
# 12240                0  17.240759
# 12253                0  13.134197
# 12339                0  10.777752
# 12345                0  12.007026
# 12425                0  12.286578
# 12443                0  10.953168
# 12448                0  12.145919
# 12467                0  12.118255
# 12482                0  10.889466
# 12483                0  11.455884
# 12487                0  10.454946
# 12491                0  11.804167
# 12498                0  12.573118
# 12504                0  11.319040
# 12509                0  11.739489
# 12510                0  10.300007
# 12511                0  10.494517
# 12515                0  10.532386
# 12518                0  10.870573
# 12527                0  16.087237
# 12540                0  10.688114
# 12564                0  11.829678
# 12565                0  12.313774
# 12579                0  13.795776
# 12690                0  14.488185
# 12745                0  13.664660

# %%
(model_prediction_df['outcome'] == model_prediction_df['prediction_over']).value_counts()
# Out:
# True     661
# False    651
# dtype: int64

# %%
ax=None, height=0.2, 
xlim=None, ylim=None, 
title='Feature importance', xlabel='Feature importance',
ylabel='Features', importance_type='split', max_num_features=None, ignore_zero=True, figsize=None, dpi=None, 
grid=True, precision=3, **kwargs)
